# %% [markdown]
# <a href="https://colab.research.google.com/github/ferantonio1979-coder/Cybersecurity-Portfolio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Python 🐍")
# Out:
# Hello Python 🐍

# %%
# Mi primer notebook en Colab
Este notebook imprime un mensaje en Python y sirve como evidencia de práctica.
# Out:
#   File "/tmp/ipykernel_2331/690437695.py", line 2
#     Este notebook imprime un mensaje en Python y sirve como evidencia de práctica.
#          ^
# SyntaxError: invalid syntax

# %%
# mi primer notebook en Colab

# %%
# Print authorized usernames
print("hello python")
# Out:
# hello python
